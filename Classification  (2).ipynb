# %%
# Load your dataset, e.g., using pandas
import pandas as pd
data = pd.read_excel('Data.xlsx')

vr_fe_columns = data.filter(regex='VR_FE_trial_\d+')
vr_wm_columns = data.filter(regex='VR_WM_trial_\d+')
vr_ltm_columns = data.filter(regex='VR_LTM_trial_\d+')
vr_pd1_columns = data.filter(regex='VR_PD1_trial_\d+')
vr_pd2_columns = data.filter(regex='VR_PD2_trial_\d+')
# Calculate the mean of each trial
data['Mean_VR_FE'] = vr_fe_columns.mean(axis=1)
data['Mean_VR_WM'] = vr_wm_columns.mean(axis=1)
data['Mean_VR_LTM'] = vr_ltm_columns.mean(axis=1)
data['Mean_VR_PD1'] = vr_pd1_columns.mean(axis=1)
data['Mean_VR_PD2'] = vr_pd2_columns.mean(axis=1)
# Filter the data for the specified columns
data_filtered_1 = data[['Mean_VR_FE', 'Mean_VR_WM','Mean_VR_LTM', 'Mean_VR_PD1','Mean_VR_PD2']]


X = data_filtered_1  # Features
y = data['FL_group']  # Labels
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train)
X_train_lda = lda.transform(X_train)
X_test_lda = lda.transform(X_test)
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
#training the model using train set 
classifier.fit(X_train_lda, y_train)
#predicting the model using test set
y_pred = classifier.predict(X_test_lda)

#calculating the accuracy of prediction
accuracy = accuracy_score(y_test, y_pred)
print('Results for Frontal lobe in VR')

print('\nTest set:\n',y_test)
print('\nPredicted set:\n',y_pred)
print('\n')
print("Accuracy of prediction:\n", accuracy)
print('\n')
from sklearn.metrics import confusion_matrix



# Compute the confusion matrix
conf_matrix = confusion_matrix( y_test,y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Results for Frontal lobe in VR
#
# Test set:
#  3      Low FL
# 2      Low FL
# 30    High FL
# 21    High FL
# 22    High FL
# 41    High FL
# 19    High FL
# 35    High FL
# 34    High FL
# Name: FL_group, dtype: object
#
# Predicted set:
#  ['Low FL' 'Low FL' 'High FL' 'High FL' 'High FL' 'High FL' 'Low FL'
#  'High FL' 'Low FL']
#
#
# Accuracy of prediction:
#  0.7777777777777778
#
#
# Confusion Matrix:
# [[5 2]
#  [0 2]]

# %%
X = data_filtered_1  # Features
y = data['MTL_group']  # Labels
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train)
X_train_lda = lda.transform(X_train)
X_test_lda = lda.transform(X_test)
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(X_train_lda, y_train)
y_pred = classifier.predict(X_test_lda)
accuracy = accuracy_score(y_test, y_pred)
print('Results for Medial temporal lobe in VR')
print('\nTest set:\n',y_test)
print('\nPredicted set:\n',y_pred)
print('\n')
print("Accuracy of prediction:\n", accuracy)
print('\n')

conf_matrix = confusion_matrix(y_test,y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Results for Medial temporal lobe in VR
#
# Test set:
#  3     High MTL
# 2      Low MTL
# 30    High MTL
# 21     Low MTL
# 22    High MTL
# 41     Low MTL
# 19    High MTL
# 35    High MTL
# 34     Low MTL
# Name: MTL_group, dtype: object
#
# Predicted set:
#  ['Low MTL' 'High MTL' 'Low MTL' 'Low MTL' 'High MTL' 'Low MTL' 'High MTL'
#  'High MTL' 'Low MTL']
#
#
# Accuracy of prediction:
#  0.6666666666666666
#
#
# Confusion Matrix:
# [[3 2]
#  [1 3]]

# %%
ts_fe_columns = data.filter(regex='TS_FE_trial_\d+')
ts_wm_columns = data.filter(regex='TS_WM_trial_\d+')
ts_ltm_columns = data.filter(regex='TS_LTM_trial_\d+')
ts_pd1_columns = data.filter(regex='TS_PD1_trial_\d+')
ts_pd2_columns = data.filter(regex='TS_PD2_trial_\d+')
# Calculate the mean of each trial
data['Mean_TS_FE'] = ts_fe_columns.mean(axis=1)
data['Mean_TS_WM'] = ts_wm_columns.mean(axis=1)
data['Mean_TS_LTM'] = ts_ltm_columns.mean(axis=1)
data['Mean_TS_PD1'] = ts_pd1_columns.mean(axis=1)
data['Mean_TS_PD2'] = ts_pd2_columns.mean(axis=1)
# Filter the data for the specified columns
data_filtered_2 = data[['Mean_TS_FE', 'Mean_TS_WM','Mean_TS_LTM', 'Mean_TS_PD1','Mean_TS_PD2']]


X = data_filtered_2  # Features
y = data['MTL_group']  # Labels
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train)
X_train_lda = lda.transform(X_train)
X_test_lda = lda.transform(X_test)
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(X_train_lda, y_train)
y_pred = classifier.predict(X_test_lda)
accuracy = accuracy_score(y_test, y_pred)
print('Results for Medial Temporal lobe in TS')
print('\nTest set:\n',y_test)
print('\nPredicted set:\n',y_pred)
print('\n')
print("Accuracy of prediction:\n", accuracy)
print('\n')
conf_matrix = confusion_matrix(y_test,y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Results for Medial Temporal lobe in TS
#
# Test set:
#  3     High MTL
# 2      Low MTL
# 30    High MTL
# 21     Low MTL
# 22    High MTL
# 41     Low MTL
# 19    High MTL
# 35    High MTL
# 34     Low MTL
# Name: MTL_group, dtype: object
#
# Predicted set:
#  ['High MTL' 'Low MTL' 'Low MTL' 'Low MTL' 'High MTL' 'High MTL' 'Low MTL'
#  'High MTL' 'Low MTL']
#
#
# Accuracy of prediction:
#  0.6666666666666666
#
#
# Confusion Matrix:
# [[3 2]
#  [1 3]]

# %%
X = data_filtered_2  # Features
y = data['MTL_group']  # Labels
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train)
X_train_lda = lda.transform(X_train)
X_test_lda = lda.transform(X_test)
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(X_train_lda, y_train)
y_pred = classifier.predict(X_test_lda)
accuracy = accuracy_score(y_test, y_pred)
print('\nTest set:\n',y_test)
print('\nPredicted set:\n',y_pred)
print('\n')
print("Accuracy of prediction:\n", accuracy)
print('\n')
from sklearn.metrics import confusion_matrix



# Compute the confusion matrix
conf_matrix = confusion_matrix( y_test,y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Test set:
#  3     High MTL
# 2      Low MTL
# 30    High MTL
# 21     Low MTL
# 22    High MTL
# 41     Low MTL
# 19    High MTL
# 35    High MTL
# 34     Low MTL
# 33    High MTL
# 43    High MTL
# 32    High MTL
# 23    High MTL
# 17     Low MTL
# 31    High MTL
# 29    High MTL
# 36     Low MTL
# 40    High MTL
# 4      Low MTL
# 24    High MTL
# 14     Low MTL
# 10     Low MTL
# Name: MTL_group, dtype: object
#
# Predicted set:
#  ['Low MTL' 'Low MTL' 'Low MTL' 'Low MTL' 'High MTL' 'Low MTL' 'Low MTL'
#  'High MTL' 'Low MTL' 'Low MTL' 'Low MTL' 'Low MTL' 'High MTL' 'High MTL'
#  'Low MTL' 'High MTL' 'High MTL' 'High MTL' 'High MTL' 'High MTL'
#  'High MTL' 'High MTL']
#
#
# Accuracy of prediction:
#  0.45454545454545453
#
#
# Confusion Matrix:
# [[6 7]
#  [5 4]]
